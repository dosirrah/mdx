# %% [markdown]
# # Example with multiple references.
#
# This is a file with multiple sections with cross-references.
#
# This is a reference to Section #one before the section in the file.
#
# This is a reference to Figure #fig:foo.

# %% [markdown]
# ## @one Plotting a Sine Wave

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
frequency = 5  # Frequency in Hz
sampling_rate = 1000  # Samples per second
duration = 1  # Duration in seconds

# Time array
t = np.linspace(0, duration, sampling_rate * duration)

# Generate sine wave
y = np.sin(2 * np.pi * frequency * t)

# Plot the sine wave
plt.figure(figsize=(8, 4))
plt.plot(t, y, label=f'{frequency} Hz Sine Wave')
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.title('Sine Wave')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# <center>*Figure @fig:foo:* The is a sine wave</center>
#
# This is a reference to Section #one after the label has appeared in the file.
